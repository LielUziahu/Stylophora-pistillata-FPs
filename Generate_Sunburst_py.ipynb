# %% [markdown]
# <a href="https://colab.research.google.com/github/LielUziahu/Stylophora-pistillata-FPs/blob/main/Generate_Sunburst_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Load the data
file_path = 'Categorized_Gene_Table_HF_NF_with_LFC_no_unknown.csv'
try:
    df = pd.read_csv(file_path)
except FileNotFoundError:
    print("File not found. Please ensure 'Categorized_Gene_Table_HF_NF_with_LFC_no_unknown.csv' is in the correct directory.")
    # Fallback for demonstration if file isn't found, creating a dummy set for demonstration structure
    df = pd.DataFrame(columns=['Morph', 'Category', 'Sub-Category', 'Gene Symbol', 'LFC', 'Description'])
    print("Created dummy DataFrame for demonstration.")

# Clean data: Ensure no missing values in grouping columns and 'Description'
df = df.dropna(subset=['Morph', 'Category', 'Sub-Category', 'Gene Symbol', 'LFC', 'Description'])

print("Data loaded and cleaned.")
print("DataFrame Info after loading and cleaning:")
df.info()
print("First 5 rows of the DataFrame:")
print(df.head())
# Out:
# Data loaded and cleaned.
# DataFrame Info after loading and cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Category                           232 non-null    object
#  1   Sub-Category                       232 non-null    object
#  2   Morph                              232 non-null    object
#  3   Gene Symbol                        232 non-null    object
#  4   Description                        232 non-null    object
#  5   LFC                                232 non-null    float64
#  6   Biological Function & Explanation  232 non-null    object
#  7   Reference                          232 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 14.6+ KB
# First 5 rows of the DataFrame:
#    Category Sub-Category Morph   Gene Symbol  \
# ...

# %% [markdown]
# ### 2. Generate Individual Sunburst Charts for Each Morph

# %%
# Get unique 'Morph' values
unique_morphs = df['Morph'].unique()

# Initialize an empty dictionary to store chart figures
morph_charts = {}

# Loop through each unique 'Morph' value
for morph_value in unique_morphs:
    # Filter the DataFrame for the current morph
    df_filtered = df[df['Morph'] == morph_value].copy()

    # Create a Sunburst chart for the filtered data, using absolute LFC values
    fig = px.sunburst(
        df_filtered,
        path=['Morph', 'Category', 'Sub-Category', 'Gene Symbol'], # Include 'Morph' as the central parent
        values=abs(df_filtered['LFC']),
        title=f'{morph_value} Gene Expression Sunburst Chart',
        hover_data=['Description'] # Add Description to hover information
    )

    # Update hovertemplate to show 'LFC' instead of 'value' and specify font size
    fig.update_traces(
        hovertemplate='<b>%{label}</b><br>LFC: %{value:.2f}<br>Description: %{customdata[0]}<extra></extra>',
        insidetextfont=dict(size=18), # Increase font size for text inside segments (should affect central parent)
        outsidetextfont=dict(size=14)
    )

    # Store the generated figure in the dictionary
    morph_charts[morph_value] = fig

print(f"Generated {len(morph_charts)} individual sunburst charts for Morphs: {list(morph_charts.keys())}")
# Out:
# Generated 2 individual sunburst charts for Morphs: ['HF', 'NF']

# %% [markdown]
# ### 3. Combine and Display Sunburst Charts Side-by-Side (Full HD, Serif Font, Custom Title)

# %%
# Get the number of individual charts
num_charts = len(morph_charts)

# Remove subplot titles as requested
subplot_titles = [''] * num_charts

# Create a subplot figure with 1 row and num_charts columns
# Specify 'domain' type for each subplot, which is suitable for sunburst charts
fig = make_subplots(
    rows=1,
    cols=num_charts,
    specs=[[{'type': 'domain'}] * num_charts],
    subplot_titles=subplot_titles
)

# Iterate through the individual charts and add them to the subplot figure
for i, (morph_name, individual_fig) in enumerate(morph_charts.items()):
    # Add each trace from the individual figure to the combined figure
    # Sunburst charts typically have one trace, so we access the first one
    fig.add_trace(individual_fig.data[0], row=1, col=i + 1)

# Update the layout with a main title, increased size, and serif font
fig.update_layout(
    title_text='Gene Expression in <i>S. pistillata</i> planulae morphs',
    title_x=0.5,
    title_font_size=24, # Increased main title font size
    width=1920,
    height=1080,
    font_family='serif' # Set global font to serif
)

# Display the combined figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 4. Save Combined Sunburst Charts to HTML

# %%
fig.write_html('combined_sunburst_charts.html')
print("Combined Sunburst chart saved as combined_sunburst_charts.html")
# Out:
# Combined Sunburst chart saved as combined_sunburst_charts.html

# %% [markdown]
# ## Save Combined Sunburst Charts
#
# ### Subtask:
# Save the final combined interactive Sunburst chart figure as an HTML file, allowing for easy sharing and exploration of the gene expression data across different 'Morph' categories.

# %% [markdown]
# **Reasoning**:
# To complete the subtask, I will save the combined Plotly figure `fig` as an HTML file named 'combined_sunburst_charts.html' using `fig.write_html()` and then print a confirmation message.

# %%
fig.write_html('combined_sunburst_charts.html')
print("Combined Sunburst chart saved as combined_sunburst_charts.html")
# Out:
# Combined Sunburst chart saved as combined_sunburst_charts.html

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm the successful creation and saving of the combined Sunburst charts for each morph, ready for review.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The final task was to confirm the successful creation and saving of the combined Sunburst charts for each morph, ready for review.
# Yes, the combined Sunburst charts were successfully created and saved as an HTML file, ready for review.
#
# ### Data Analysis Key Findings
# *   The DataFrame `df` was validated and confirmed to contain all necessary columns ('Morph', 'Category', 'Sub-Category', 'Gene Symbol', 'LFC') with appropriate data types and no missing values, making it suitable for generating Sunburst charts.
# *   Two individual interactive Sunburst charts were successfully generated, one for each unique 'Morph' value ('HF' and 'NF'). Each chart visualized gene expression using `['Category', 'Sub-Category', 'Gene Symbol']` as the hierarchy and 'LFC' for values.
# *   These two individual charts were then successfully combined into a single Plotly figure using `plotly.subplots.make_subplots`, arranged side-by-side with distinct titles for each morph and a main title "Combined Gene Expression Sunburst Charts: HF vs. NF".
# *   The combined interactive Sunburst chart was saved as an HTML file named `combined_sunburst_charts.html`, ensuring it can be easily shared and explored.
#
# ### Insights or Next Steps
# *   The interactive `combined_sunburst_charts.html` file provides a comprehensive and easily navigable visualization for comparing gene expression profiles between 'HF' and 'NF' morphs.
# *   The saved HTML file can be readily shared with collaborators or stakeholders, allowing them to explore the gene expression data in detail without needing specific software or coding knowledge.

# %% [markdown]
# # Task
# Generate and save a combined interactive Sunburst chart as an HTML file using data from "Categorized_Gene_Table_HF_NF_with_LFC_no_unknown.csv", visualizing gene expression across different 'Morph' categories, and confirm its successful creation.

# %% [markdown]
# ## Combine and Display Sunburst Charts Side-by-Side
#
# ### Subtask:
# Use `plotly.subplots.make_subplots` to arrange the individual Sunburst charts created in the previous step into a single figure, displayed side-by-side. Each chart will have its own title indicating the 'Morph' it represents, and the combined figure will have a main title.

# %% [markdown]
# **Reasoning**:
# To combine and display the individual Sunburst charts side-by-side as requested, I will use `plotly.subplots.make_subplots` to create a figure with multiple subplots. I will then iterate through the `morph_charts` dictionary, adding each individual Sunburst chart as a trace to the combined figure, ensuring each has its own subplot title and the overall figure has a main title.

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Get the number of individual charts
num_charts = len(morph_charts)

# Get subplot titles from the keys of morph_charts
subplot_titles = [f'{morph} Gene Expression' for morph in morph_charts.keys()]

# Create a subplot figure with 1 row and num_charts columns
# Specify 'domain' type for each subplot, which is suitable for sunburst charts
fig = make_subplots(
    rows=1,
    cols=num_charts,
    specs=[[{'type': 'domain'}] * num_charts],
    subplot_titles=subplot_titles
)

# Iterate through the individual charts and add them to the subplot figure
for i, (morph_name, individual_fig) in enumerate(morph_charts.items()):
    # Add each trace from the individual figure to the combined figure
    # Sunburst charts typically have one trace, so we access the first one
    fig.add_trace(individual_fig.data[0], row=1, col=i + 1)

# Update the layout with a main title
fig.update_layout(title_text='Combined Gene Expression Sunburst Charts: HF vs. NF', title_x=0.5)

# Display the combined figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Save Combined Sunburst Charts
#
# ### Subtask:
# Save the final combined interactive Sunburst chart figure as an HTML file, allowing for easy sharing and exploration of the gene expression data across different 'Morph' categories.

# %% [markdown]
# **Reasoning**:
# To complete the subtask, I will save the combined Plotly figure `fig` as an HTML file named 'combined_sunburst_charts.html' using `fig.write_html()` and then print a confirmation message.

# %%
fig.write_html('combined_sunburst_charts.html')
print("Combined Sunburst chart saved as combined_sunburst_charts.html")
# Out:
# Combined Sunburst chart saved as combined_sunburst_charts.html

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm the successful creation and saving of the combined Sunburst charts for each morph, ready for review.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# Yes, the combined Sunburst charts for each morph were successfully created and saved as an HTML file, ready for review.
#
# ### Data Analysis Key Findings
# *   A combined interactive Plotly figure was successfully generated, arranging multiple Sunburst charts side-by-side.
# *   Each individual Sunburst chart within the combined figure represents gene expression for a specific 'Morph' category and is appropriately titled (e.g., 'HF Gene Expression', 'NF Gene Expression').
# *   The overall combined figure was given a main title: 'Combined Gene Expression Sunburst Charts: HF vs. NF'.
# *   The final combined interactive Sunburst chart was successfully saved as an HTML file named `combined_sunburst_charts.html`, ensuring its portability and interactive exploration capabilities.
#
# ### Insights or Next Steps
# *   The `combined_sunburst_charts.html` file provides a convenient and interactive way to explore and compare gene expression patterns across different morphs (HF vs. NF).
# *   Further analysis could involve sharing this interactive visualization with stakeholders for detailed biological interpretation and identifying specific gene categories driving observed differences between morphs.
